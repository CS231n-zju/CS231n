# %% [markdown]
# # 载入数据集

# %%
import cv2
import h5py
import random
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from tqdm import tqdm
from scipy import stats, integrate
from sklearn.utils import shuffle

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
n = 25000
n_class = 1
width = 299 # 224

X = np.zeros((n, width, width, 3), dtype=np.uint8)
y = np.zeros((n), dtype=np.uint8)

epochs = int(n/2)
for i in tqdm(range(epochs)):
    X[i] = cv2.resize(cv2.imread('./train/cat.%s.jpg' % i), (width, width))
    y[i] = 0
    X[epochs + i] = cv2.resize(cv2.imread('./train/dog.%s.jpg' % i), (width, width))
    y[epochs + i] = 1
# Out:
# 100%|██████████| 12500/12500 [00:41<00:00, 298.74it/s]

# %% [markdown]
# # 数据集可视化

# %%
plt.figure(figsize=(12, 6))
for i in range(8):
    random_index = random.randint(0, n-1)
    plt.subplot(2, 4, i+1)
    plt.imshow(X[random_index][:,:,::-1])
    if y[random_index] == 0:
        plt.title('cat')
    else:
        plt.title('dog')

# %%
train_size = []

for i in tqdm(range(n/2)):
    img = cv2.imread('./train/cat.%s.jpg' % i)
    train_size.append(img.shape)
    img = cv2.imread('./train/dog.%s.jpg' % i)
    train_size.append(img.shape)
    
df = pd.DataFrame(train_size, columns=["x", "y", "z"])
# Out:
# 100%|██████████| 12500/12500 [00:34<00:00, 358.43it/s]

# %%
sns.set(color_codes=True)
sns.jointplot(x="x", y="y", data=df);
plt.figure(figsize=(12, 6))

# %%
test_size = []

for i in tqdm(range(12500)):
    img = cv2.imread('./test/%s.jpg' % (i+1))
    test_size.append(img.shape)
    
df_test = pd.DataFrame(test_size, columns=["x", "y", "z"])
# Out:
# 100%|██████████| 12500/12500 [00:27<00:00, 446.78it/s]

# %%
sns.set(color_codes=True)
sns.jointplot(x="x", y="y", data=df_test);
plt.figure(figsize=(12, 6))

# %% [markdown]
# # 异常图分析

# %%
from scipy.stats import iqr

plt.figure(figsize=(12, 6))
arr_x = X.reshape((25000, 299*299*3))
arr_iq = iqr(arr_x, axis=1)
sns.set(color_codes=True)
sns.distplot(arr_iq);
print(arr_iq.shape)
# Out:
# (25000,)

# %%
x_ids =  np.where(arr_iq < 10)[0]
x_ids
# Out:
# array([ 2939,  4522,  7564,  8068,  8456,  8470, 10029, 11928, 15897,
#        16253, 16494, 16627, 16718, 16888, 18038, 21236])

# %%
plt.figure(figsize=(12, 8))
for i in range(6):
    pic_id = int(x_ids[i])
    plt.subplot(2, 3, i+1)
    plt.imshow(X[pic_id][:,:,::-1])
    if y[pic_id] == 0:
        plt.title('cat - ' + str(pic_id))
    else:
        plt.title('dog - ' + str(pic_id - 12500))

# %%
x_ids =  np.where(arr_iq > 230)[0]
x_ids
# Out:
# array([ 7032, 11301, 11565, 15377, 22901, 23297])

# %%
plt.figure(figsize=(12, 8))
for i in range(6):
    pic_id = int(x_ids[i])
    plt.subplot(2, 3, i+1)
    plt.imshow(X[pic_id][:,:,::-1])
    if y[pic_id] == 0:
        plt.title('cat - ' + str(pic_id))
    else:
        plt.title('dog - ' + str(pic_id - 12500))

# %% [markdown]
# # 导出特征

# %%
from keras.layers import *
from keras.models import *
from keras.applications import *
from keras.optimizers import *
from keras.regularizers import *
from keras.applications.inception_v3 import preprocess_input
# Out:
# Using TensorFlow backend.

# %%
def get_features(MODEL, data=X, prefix=''):
    cnn_model = MODEL(include_top=False, input_shape=(width, width, 3), weights='imagenet')
    
    inputs = Input((width, width, 3))
    x = inputs
    x = Lambda(preprocess_input, name='preprocessing')(x)
    x = cnn_model(x)
    x = GlobalAveragePooling2D()(x)
    cnn_model = Model(inputs, x)

    features = cnn_model.predict(data, batch_size=64, verbose=1)
    
    with h5py.File("./cache/{0}fea_{1}.h5".format(prefix, MODEL.__name__)) as h:
        h.create_dataset("features", data=features)
        
    return features

# %%
inception_features = get_features(InceptionV3, X, 'train_')
xception_features = get_features(Xception, X, 'train_')
inceRes_features = get_features(InceptionResNetV2, X, 'train_')
resnet_features = get_features(ResNet50, X, 'train_')

features = np.concatenate([inception_features, xception_features, inceRes_features], axis=-1)
features.shape
# Out:
# 25000/25000 [==============================] - 83s

# %%
def get_data(filename):
    with h5py.File(filename, 'r') as data:
        return np.array(data['features'])

# %%
inception_features = get_data('./cache/train_fea_InceptionV3.h5')
xception_features = get_data('./cache/train_fea_Xception.h5')
inceRes_features = get_data('./cache/train_fea_InceptionResNetV2.h5')
resnet_features = get_data('./cache/train_fea_ResNet50.h5')

# features = np.concatenate([inception_features, xception_features, inceRes_features], axis=-1)
# features.shape

# %% [markdown]
# # 训练模型 / InceptionV3 / 0.05484

# %%
features = inception_features
X, y_train = shuffle(features, y)
features.shape
# Out:
# (25000, 2048)

# %%
inputs = Input(features.shape[1:])
x = inputs
x = Dropout(0.5)(x)
x = Dense(1, activation='sigmoid')(x)
model = Model(inputs, x)
adam = Adam(lr=0.001)
model.compile(optimizer=adam,
              loss='binary_crossentropy',
              metrics=['accuracy'])

h = model.fit(X, y_train, batch_size=256, epochs=15, 
              shuffle=True, 
              validation_split=0.1)
# Out:
# Train on 22500 samples, validate on 2500 samples
# Epoch 1/15
# 22500/22500 [==============================] - 0s - loss: 0.2122 - acc: 0.9257 - val_loss: 0.0627 - val_acc: 0.9872
# Epoch 2/15
# 22500/22500 [==============================] - 0s - loss: 0.0598 - acc: 0.9860 - val_loss: 0.0412 - val_acc: 0.9912
# Epoch 3/15
# 22500/22500 [==============================] - 0s - loss: 0.0468 - acc: 0.9878 - val_loss: 0.0330 - val_acc: 0.9936
# Epoch 4/15
# 22500/22500 [==============================] - 0s - loss: 0.0380 - acc: 0.9899 - val_loss: 0.0296 - val_acc: 0.9932
# Epoch 5/15
# 22500/22500 [==============================] - 0s - loss: 0.0355 - acc: 0.9900 - val_loss: 0.0269 - val_acc: 0.9936
# Epoch 6/15
# 22500/22500 [==============================] - 0s - loss: 0.0319 - acc: 0.9902 - val_loss: 0.0255 - val_acc: 0.9936
# Epoch 7/15
# 22500/22500 [==============================] - 0s - loss: 0.0308 - acc: 0.9907 - val_loss: 0.0245 - val_acc: 0.9936
# Epoch 8/15
# 22500/22500 [==============================] - 0s - loss: 0.0310 - acc: 0.9911 - val_loss: 0.0244 - val_acc: 0.9940
# Epoch 9/15
# 22500/22500 [==============================] - 0s - loss: 0.0280 - acc: 0.9909 - val_loss: 0.0239 - val_acc: 0.9948
# Epoch 10/15
# 22500/22500 [==============================] - 0s - loss: 0.0282 - acc: 0.9910 - val_loss: 0.0233 - val_acc: 0.9948
# %%
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(h.history['loss'])
plt.plot(h.history['val_loss'])
plt.legend(['loss', 'val_loss'])
plt.ylabel('loss')
plt.xlabel('epoch')

plt.subplot(1, 2, 2)
plt.plot(h.history['acc'])
plt.plot(h.history['val_acc'])
plt.legend(['acc', 'val_acc'])
plt.ylabel('acc')
plt.xlabel('epoch')
# Out:
# Text(0.5,0,'epoch')

# %% [markdown]
# # 训练模型 / InceptionResNetV2 / 0.05096

# %%
features = inceRes_features
X, y_train = shuffle(features, y)
features.shape
# Out:
# (25000, 1536)

# %%
inputs = Input(features.shape[1:])
x = inputs
x = Dropout(0.5)(x)
x = Dense(1, activation='sigmoid')(x)
model = Model(inputs, x)
adam = Adam(lr=0.001)
model.compile(optimizer=adam,
              loss='binary_crossentropy',
              metrics=['accuracy'])

h = model.fit(X, y_train, batch_size=256, epochs=15, 
              shuffle=True, 
              validation_split=0.1)
# Out:
# Train on 22500 samples, validate on 2500 samples
# Epoch 1/15
# 22500/22500 [==============================] - 0s - loss: 0.1799 - acc: 0.9456 - val_loss: 0.0594 - val_acc: 0.9880
# Epoch 2/15
# 22500/22500 [==============================] - 0s - loss: 0.0503 - acc: 0.9900 - val_loss: 0.0426 - val_acc: 0.9908
# Epoch 3/15
# 22500/22500 [==============================] - 0s - loss: 0.0376 - acc: 0.9908 - val_loss: 0.0362 - val_acc: 0.9924
# Epoch 4/15
# 22500/22500 [==============================] - 0s - loss: 0.0334 - acc: 0.9923 - val_loss: 0.0333 - val_acc: 0.9924
# Epoch 5/15
# 22500/22500 [==============================] - 0s - loss: 0.0281 - acc: 0.9931 - val_loss: 0.0314 - val_acc: 0.9920
# Epoch 6/15
# 22500/22500 [==============================] - 0s - loss: 0.0270 - acc: 0.9926 - val_loss: 0.0312 - val_acc: 0.9924
# Epoch 7/15
# 22500/22500 [==============================] - 0s - loss: 0.0256 - acc: 0.9932 - val_loss: 0.0300 - val_acc: 0.9928
# Epoch 8/15
# 22500/22500 [==============================] - 0s - loss: 0.0237 - acc: 0.9933 - val_loss: 0.0290 - val_acc: 0.9928
# Epoch 9/15
# 22500/22500 [==============================] - 0s - loss: 0.0233 - acc: 0.9934 - val_loss: 0.0288 - val_acc: 0.9932
# Epoch 10/15
# 22500/22500 [==============================] - 0s - loss: 0.0227 - acc: 0.9936 - val_loss: 0.0281 - val_acc: 0.9928
# Epoch 11/15
# 22500/22500 [==============================] - 0s - loss: 0.0211 - acc: 0.9941 - val_loss: 0.0282 - val_acc: 0.9928
# Epoch 12/15
# 22500/22500 [==============================] - 0s - loss: 0.0209 - acc: 0.9940 - val_loss: 0.0277 - val_acc: 0.9928
# Epoch 13/15
# 22500/22500 [==============================] - 0s - loss: 0.0210 - acc: 0.9940 - val_loss: 0.0275 - val_acc: 0.9924
# Epoch 14/15
# 22500/22500 [==============================] - 0s - loss: 0.0205 - acc: 0.9942 - val_loss: 0.0279 - val_acc: 0.9928
# Epoch 15/15
# 22500/22500 [==============================] - 0s - loss: 0.0218 - acc: 0.9939 - val_loss: 0.0274 - val_acc: 0.9928

# %% [markdown]
# # 可视化训练过程 / InceptionResNetV2

# %%
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(h.history['loss'])
plt.plot(h.history['val_loss'])
plt.legend(['loss', 'val_loss'])
plt.ylabel('loss')
plt.xlabel('epoch')

plt.subplot(1, 2, 2)
plt.plot(h.history['acc'])
plt.plot(h.history['val_acc'])
plt.legend(['acc', 'val_acc'])
plt.ylabel('acc')
plt.xlabel('epoch')
# Out:
# Text(0.5,0,'epoch')

# %% [markdown]
# # 训练模型 / ResNet50 / 0.07031

# %%
features = resnet_features
X, y_train = shuffle(features, y)
features.shape
# Out:
# (25000, 2048)

# %%
inputs = Input(features.shape[1:])
x = inputs
x = Dropout(0.5)(x)
x = Dense(1, activation='sigmoid')(x)
model = Model(inputs, x)
adam = Adam(lr=0.001)
model.compile(optimizer=adam,
              loss='binary_crossentropy',
              metrics=['accuracy'])

h = model.fit(X, y_train, batch_size=256, epochs=60, 
              shuffle=True, 
              validation_split=0.1)
# Out:
# Train on 22500 samples, validate on 2500 samples
# Epoch 1/60
# 22500/22500 [==============================] - 0s - loss: 0.7177 - acc: 0.5451 - val_loss: 0.6424 - val_acc: 0.6300
# Epoch 2/60
# 22500/22500 [==============================] - 0s - loss: 0.6508 - acc: 0.6193 - val_loss: 0.6303 - val_acc: 0.6492
# Epoch 3/60
# 22500/22500 [==============================] - 0s - loss: 0.6395 - acc: 0.6342 - val_loss: 0.6215 - val_acc: 0.6576
# Epoch 4/60
# Epoch 46/60
# 22500/22500 [==============================] - 0s - loss: 0.5916 - acc: 0.6841 - val_loss: 0.5716 - val_acc: 0.7100
# Epoch 47/60
# 22500/22500 [==============================] - 0s - loss: 0.5927 - acc: 0.6855 - val_loss: 0.5706 - val_acc: 0.7168
# Epoch 48/60
# 22500/22500 [==============================] - 0s - loss: 0.5908 - acc: 0.6860 - val_loss: 0.5715 - val_acc: 0.7092
# Epoch 49/60
# 22500/22500 [==============================] - 0s - loss: 0.5918 - acc: 0.6855 - val_loss: 0.5689 - val_acc: 0.7212
# Epoch 50/60
# 22500/22500 [==============================] - 0s - loss: 0.5905 - acc: 0.6854 - val_loss: 0.5696 - val_acc: 0.7148
# Epoch 51/60
# 22500/22500 [==============================] - 0s - loss: 0.5926 - acc: 0.6846 - val_loss: 0.5683 - val_acc: 0.7212
# Epoch 52/60
# 22500/22500 [==============================] - 0s - loss: 0.5910 - acc: 0.6885 - val_loss: 0.5681 - val_acc: 0.7248
# Epoch 53/60
# 22500/22500 [==============================] - 0s - loss: 0.5915 - acc: 0.6838 - val_loss: 0.5681 - val_acc: 0.7216
# Epoch 54/60
# 22500/22500 [==============================] - 0s - loss: 0.5910 - acc: 0.6879 - val_loss: 0.5681 - val_acc: 0.7224
# Epoch 55/60
# 22500/22500 [==============================] - 0s - loss: 0.5897 - acc: 0.6876 - val_loss: 0.5668 - val_acc: 0.7216
# Epoch 56/60
# 22500/22500 [==============================] - 0s - loss: 0.5907 - acc: 0.6869 - val_loss: 0.5698 - val_acc: 0.7124
# Epoch 57/60
# 22500/22500 [==============================] - 0s - loss: 0.5919 - acc: 0.6873 - val_loss: 0.5684 - val_acc: 0.7176
# Epoch 58/60
# 22500/22500 [==============================] - 0s - loss: 0.5901 - acc: 0.6876 - val_loss: 0.5690 - val_acc: 0.7168
# Epoch 59/60
# 22500/22500 [==============================] - 0s - loss: 0.5898 - acc: 0.6892 - val_loss: 0.5671 - val_acc: 0.7224
# Epoch 60/60
# 22500/22500 [==============================] - 0s - loss: 0.5916 - acc: 0.6856 - val_loss: 0.5662 - val_acc: 0.7256

# %% [markdown]
# # 可视化训练过程 / ResNet50

# %%
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(h.history['loss'])
plt.plot(h.history['val_loss'])
plt.legend(['loss', 'val_loss'])
plt.ylabel('loss')
plt.xlabel('epoch')

plt.subplot(1, 2, 2)
plt.plot(h.history['acc'])
plt.plot(h.history['val_acc'])
plt.legend(['acc', 'val_acc'])
plt.ylabel('acc')
plt.xlabel('epoch')
# Out:
# Text(0.5,0,'epoch')

# %% [markdown]
# # InceptionV3 / Xception / InceptionResNetV2 - 0.05438

# %%
features =  np.concatenate([inception_features, xception_features, inceRes_features], axis=-1)
X, y_train = shuffle(features, y)
features.shape
# Out:
# (25000, 5632)

# %%
inputs = Input(features.shape[1:])
x = inputs
x = Dropout(0.5)(x)
x = Dense(1, activation='sigmoid')(x)
model = Model(inputs, x)
adam = Adam(lr=0.001)
model.compile(optimizer=adam,
              loss='binary_crossentropy',
              metrics=['accuracy'])

h = model.fit(X, y_train, batch_size=256, epochs=12, 
              shuffle=True, 
              validation_split=0.1)
# Out:
# Train on 22500 samples, validate on 2500 samples
# Epoch 1/12
# 22500/22500 [==============================] - 0s - loss: 0.0791 - acc: 0.9745 - val_loss: 0.0257 - val_acc: 0.9936
# Epoch 2/12
# 22500/22500 [==============================] - 0s - loss: 0.0227 - acc: 0.9937 - val_loss: 0.0206 - val_acc: 0.9944
# Epoch 3/12
# 22500/22500 [==============================] - 0s - loss: 0.0184 - acc: 0.9948 - val_loss: 0.0189 - val_acc: 0.9948
# Epoch 4/12
# 22500/22500 [==============================] - 0s - loss: 0.0163 - acc: 0.9952 - val_loss: 0.0176 - val_acc: 0.9948
# Epoch 5/12
# %%
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(h.history['loss'])
plt.plot(h.history['val_loss'])
plt.legend(['loss', 'val_loss'])
plt.ylabel('loss')
plt.xlabel('epoch')

plt.subplot(1, 2, 2)
plt.plot(h.history['acc'])
plt.plot(h.history['val_acc'])
plt.legend(['acc', 'val_acc'])
plt.ylabel('acc')
plt.xlabel('epoch')
# Out:
# Text(0.5,0,'epoch')

# %% [markdown]
# # Xception / InceptionResNetV2 - 0.04905

# %%
features =  np.concatenate([xception_features, inceRes_features], axis=-1)
X, y_train = shuffle(features, y)
features.shape
# Out:
# (25000, 3584)

# %%
inputs = Input(features.shape[1:])
x = inputs
x = Dropout(0.5)(x)
x = Dense(1, activation='sigmoid')(x)
model = Model(inputs, x)
adam = Adam(lr=0.001)
model.compile(optimizer=adam,
              loss='binary_crossentropy',
              metrics=['accuracy'])

h = model.fit(X, y_train, batch_size=256, epochs=12, 
              shuffle=True, 
              validation_split=0.1)
# Out:
# Train on 22500 samples, validate on 2500 samples
# Epoch 1/12
# 22500/22500 [==============================] - 0s - loss: 0.1082 - acc: 0.9733 - val_loss: 0.0285 - val_acc: 0.9944
# Epoch 2/12
# 22500/22500 [==============================] - 0s - loss: 0.0298 - acc: 0.9931 - val_loss: 0.0202 - val_acc: 0.9948
# Epoch 3/12
# 22500/22500 [==============================] - 0s - loss: 0.0236 - acc: 0.9938 - val_loss: 0.0175 - val_acc: 0.9952
# Epoch 4/12
# 22500/22500 [==============================] - 0s - loss: 0.0210 - acc: 0.9943 - val_loss: 0.0152 - val_acc: 0.9948
# Epoch 5/12
# 22500/22500 [==============================] - 0s - loss: 0.0190 - acc: 0.9946 - val_loss: 0.0143 - val_acc: 0.9956
# Epoch 6/12
# 22500/22500 [==============================] - 0s - loss: 0.0175 - acc: 0.9948 - val_loss: 0.0143 - val_acc: 0.9952
# Epoch 7/12
# 22500/22500 [==============================] - 0s - loss: 0.0175 - acc: 0.9950 - val_loss: 0.0150 - val_acc: 0.9952
# Epoch 8/12
# 22500/22500 [==============================] - 0s - loss: 0.0162 - acc: 0.9954 - val_loss: 0.0131 - val_acc: 0.9960
# Epoch 9/12
# 22500/22500 [==============================] - 0s - loss: 0.0161 - acc: 0.9954 - val_loss: 0.0133 - val_acc: 0.9960
# Epoch 10/12
# 22500/22500 [==============================] - 0s - loss: 0.0149 - acc: 0.9955 - val_loss: 0.0129 - val_acc: 0.9956
# Epoch 11/12
# 22500/22500 [==============================] - 0s - loss: 0.0156 - acc: 0.9954 - val_loss: 0.0127 - val_acc: 0.9956
# Epoch 12/12
# 22500/22500 [==============================] - 0s - loss: 0.0137 - acc: 0.9956 - val_loss: 0.0139 - val_acc: 0.9948

# %%
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(h.history['loss'])
plt.plot(h.history['val_loss'])
plt.legend(['loss', 'val_loss'])
plt.ylabel('loss')
plt.xlabel('epoch')

plt.subplot(1, 2, 2)
plt.plot(h.history['acc'])
plt.plot(h.history['val_acc'])
plt.legend(['acc', 'val_acc'])
plt.ylabel('acc')
plt.xlabel('epoch')
# Out:
# Text(0.5,0,'epoch')

# %% [markdown]
# # InceptionV3 / InceptionResNetV2 - 0.04791

# %%
features =  np.concatenate([inception_features, inceRes_features], axis=-1)
X, y_train = shuffle(features, y)
features.shape
# Out:
# (25000, 3584)

# %%
inputs = Input(features.shape[1:])
x = inputs
x = Dropout(0.5)(x)
x = Dense(1, activation='sigmoid')(x)
model = Model(inputs, x)
adam = Adam(lr=0.001)
model.compile(optimizer=adam,
              loss='binary_crossentropy',
              metrics=['accuracy'])

h = model.fit(X, y_train, batch_size=256, epochs=12, 
              shuffle=True, 
              validation_split=0.1)
# Out:
# Train on 22500 samples, validate on 2500 samples
# Epoch 1/12
# 22500/22500 [==============================] - 0s - loss: 0.1084 - acc: 0.9663 - val_loss: 0.0263 - val_acc: 0.9940
# Epoch 2/12
# 22500/22500 [==============================] - 0s - loss: 0.0306 - acc: 0.9922 - val_loss: 0.0186 - val_acc: 0.9968
# Epoch 3/12
# 22500/22500 [==============================] - 0s - loss: 0.0240 - acc: 0.9934 - val_loss: 0.0151 - val_acc: 0.9976
# Epoch 4/12
# 22500/22500 [==============================] - 0s - loss: 0.0212 - acc: 0.9939 - val_loss: 0.0141 - val_acc: 0.9976
# Epoch 5/12
# 22500/22500 [==============================] - 0s - loss: 0.0204 - acc: 0.9941 - val_loss: 0.0148 - val_acc: 0.9956
# Epoch 6/12
# 22500/22500 [==============================] - 0s - loss: 0.0190 - acc: 0.9943 - val_loss: 0.0153 - val_acc: 0.9948
# Epoch 7/12
# 22500/22500 [==============================] - 0s - loss: 0.0182 - acc: 0.9944 - val_loss: 0.0130 - val_acc: 0.9968
# Epoch 8/12
# 22500/22500 [==============================] - 0s - loss: 0.0171 - acc: 0.9947 - val_loss: 0.0130 - val_acc: 0.9968
# Epoch 9/12
# 22500/22500 [==============================] - 0s - loss: 0.0160 - acc: 0.9950 - val_loss: 0.0148 - val_acc: 0.9948
# Epoch 10/12
# 22500/22500 [==============================] - 0s - loss: 0.0162 - acc: 0.9951 - val_loss: 0.0127 - val_acc: 0.9972
# Epoch 11/12
# 22500/22500 [==============================] - 0s - loss: 0.0148 - acc: 0.9955 - val_loss: 0.0122 - val_acc: 0.9972
# Epoch 12/12
# 22500/22500 [==============================] - 0s - loss: 0.0155 - acc: 0.9950 - val_loss: 0.0123 - val_acc: 0.9972

# %%
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(h.history['loss'])
plt.plot(h.history['val_loss'])
plt.legend(['loss', 'val_loss'])
plt.ylabel('loss')
plt.xlabel('epoch')

plt.subplot(1, 2, 2)
plt.plot(h.history['acc'])
plt.plot(h.history['val_acc'])
plt.legend(['acc', 'val_acc'])
plt.ylabel('acc')
plt.xlabel('epoch')
# Out:
# Text(0.5,0,'epoch')

# %% [markdown]
# # 载入测试集

# %%
df_sub = pd.read_csv('./sample_submission.csv')

# %%
n_test = 12500
X_test = np.zeros((n_test, width, width, 3), dtype=np.uint8)
for i in tqdm(range(n_test)):
    X_test[i] = cv2.resize(cv2.imread('./test/%s.jpg' % (i+1)), (width, width))
# Out:
# 100%|██████████| 12500/12500 [00:37<00:00, 335.47it/s]

# %% [markdown]
# # 导出测试集特征

# %%
inception_features = get_features(InceptionV3, X_test, 'test_')
xception_features = get_features(Xception, X_test, 'test_')
inceRes_features = get_features(InceptionResNetV2, X_test, 'test_')
# resnet_features = get_features(ResNet50, X_test, 'test_')

features_test = np.concatenate([inception_features, xception_features, inceRes_features], axis=-1)
features_test.shape

# %%
inception_features = get_data('./cache/test_fea_InceptionV3.h5')
xception_features = get_data('./cache/test_fea_Xception.h5')
inceRes_features = get_data('./cache/test_fea_InceptionResNetV2.h5')
# resnet_features = get_data('./cache/test_fea_ResNet50.h5')

features_test = np.concatenate([inception_features, xception_features, inceRes_features], axis=-1)
features_test.shape
# Out:
# (12500, 5632)

# %% [markdown]
# # 预测测试集并优化输出结果

# %%
df_sub['label'] = model.predict(features_test, batch_size=128)

# %%
labels = []

for index, row in df_sub.iterrows():
    if row['label'] > 0.995:
        labels.append(0.995)
    elif row['label'] < 0.005:
        labels.append(0.005)
    else:
        labels.append(row['label'])

df_sub['label'] = labels

# %%
df_sub.head(10)
# Out:
#    id  label
# 0   1  0.995
# 1   2  0.995
# 2   3  0.995
# 3   4  0.995
# 4   5  0.005
# 5   6  0.005
# 6   7  0.005
# 7   8  0.005
# 8   9  0.005
# 9  10  0.005

# %%
df_sub.to_csv('result.csv', index=None)
